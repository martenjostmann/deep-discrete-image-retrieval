# %%
# Import Libraries
import sys
# Add path
sys.path.append("..")

import os
from src.d00_utils.query_kdtree import query_kdtree as qkdt
from src.d00_utils.query_lsh import query_lsh as qlsh

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %% [markdown]
# ## K-D Trees

# %%
kdt = qkdt(dataset="resisc") #resisc or cifar
# Out:
# Loading and preprocessing data...
# Found 31500 files belonging to 45 classes.
# Load features
# Start building KDTree
# KDTree finished in 0.6099851131439209 seconds

# %%
results = kdt.query(image_idx=3000, k=10)
# Out:
# Start searching in KDTree
# Finish searching in 0.0013659000396728516 seconds
# ../src/d04_visualisation/plot_nearest_neighbor.py:63: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   fig.add_subplot(rows, cols, idx + 1)

# %%
class_accr, accuracy, time = kdt.performance(k=100)
# Out:
# Iteration 0 / 31500
# Iteration 1000 / 31500
# Iteration 2000 / 31500
# Iteration 3000 / 31500
# Iteration 4000 / 31500
# Iteration 5000 / 31500
# Iteration 6000 / 31500
# Iteration 7000 / 31500
# Iteration 8000 / 31500
# Iteration 9000 / 31500
# Iteration 10000 / 31500
# Iteration 11000 / 31500
# Iteration 12000 / 31500
# Iteration 13000 / 31500
# Iteration 14000 / 31500
# Iteration 15000 / 31500
# Iteration 16000 / 31500
# Iteration 17000 / 31500
# Iteration 18000 / 31500
# Iteration 19000 / 31500
# Iteration 20000 / 31500
# Iteration 21000 / 31500
# Iteration 22000 / 31500
# Iteration 23000 / 31500
# Iteration 24000 / 31500
# Iteration 25000 / 31500
# Iteration 26000 / 31500
# Iteration 27000 / 31500
# Iteration 28000 / 31500
# Iteration 29000 / 31500
# Iteration 30000 / 31500
# Iteration 31000 / 31500
# 31500 searches for the 100 nearest neighbors was completed in 17.449188947677612 Seconds
# The accuracy is 0.9061320634921075

# %% [markdown]
# ## Locality Sensitive Hashing

# %%
lsh = qlsh(dataset="cifar") #resisc or cifar
# Out:
# Loading and preprocessing data...
# Load features
# Start creating min-hashes
# Start building LSH
# LSH finished in 37.84569001197815 seconds

# %%
matches = lsh.query(image_idx=0, k=10)
# Out:
# Search finished in 0.0001983642578125 seconds
# ../src/d04_visualisation/plot_nearest_neighbor.py:28: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   fig.add_subplot(rows, cols, idx + 1)

# %%
accuracy, time = lsh.performance(k=10)
# Out:
# Iteration 0 / 60000
# Iteration 1000 / 60000
# Iteration 2000 / 60000
# Iteration 3000 / 60000
# Iteration 4000 / 60000
# Iteration 5000 / 60000
# Iteration 6000 / 60000
# Iteration 7000 / 60000
# Iteration 8000 / 60000
# Iteration 9000 / 60000
# Iteration 10000 / 60000
# Iteration 11000 / 60000
# Iteration 12000 / 60000
# Iteration 13000 / 60000
# Iteration 14000 / 60000
# Iteration 15000 / 60000
# Iteration 16000 / 60000
# Iteration 17000 / 60000
# Iteration 18000 / 60000
# Iteration 19000 / 60000
# Iteration 20000 / 60000
# Iteration 21000 / 60000
# Iteration 22000 / 60000
# Iteration 23000 / 60000
# Iteration 24000 / 60000
# Iteration 25000 / 60000
# Iteration 26000 / 60000
# Iteration 27000 / 60000
# Iteration 28000 / 60000
# Iteration 29000 / 60000
# Iteration 30000 / 60000
# Iteration 31000 / 60000
# Iteration 32000 / 60000
# Iteration 33000 / 60000
# Iteration 34000 / 60000
# Iteration 35000 / 60000
# Iteration 36000 / 60000
# Iteration 37000 / 60000
# ...
